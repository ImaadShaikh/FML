# %%
n=input("Enter the number")
print(type(n))
# Out:
# Enter the number5
# <class 'str'>

# %%
x=5
if(x>2):
    print("Bigger than 2")
else:
    print("Smaller than 2")
# Out:
# Bigger than 2

# %%
x=42
if x>1:
    print("More than 1")
    if x<100:
        print("Less than 100")
print("All done")
# Out:
# More than 1
# Less than 100
# All done

# %%
x=4
if x>2:
    print("Bigger")
else:
    print("Not bigger")
print("All done")
# Out:
# Bigger
# All done

# %%
astr="Hello"
istr=int(astr)
print("First",istr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-8fba43c69405> in <cell line: 2>()
#       1 astr="Hello"
# ----> 2 istr=int(astr)
#       3 print("First",istr)
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %%
astr="123"
istr=int(astr)
print(istr)
# Out:
# 123

# %%
astr="Hello"
try:
    istr=int(astr)
    print("First",istr)
except:
    istr=-1
print("First",istr)

astr="123"
try:
    istr=int(astr)
    print(istr)
except:
    istr=-1
print(istr)
# Out:
# First -1
# 123
# 123

# %%
astr="BOb"
try:
    print("Hello")
    istr=int(str)
    print('There')
except:
    istr=-1
print("Done",istr)
# Out:
# Hello
# Done -1

# %%
def multiplication(a,b):
    return a*b

a=4
b=6
print(multiplication(a,b))
# Out:
# 24

# %%
big=max("Hello world")
small=min("Helloworld")
print(big)
print(small)
# Out:
# w
# H

# %%
smallest=None
for value in [3,41,12,9,74,15]:
    if smallest is None:
        smallest=value
    elif value<smallest:
        smallest=value
    print(smallest)
# Out:
# 3
# 3
# 3
# 3
# 3
# 3

# %%
smallest=0
for value in [3,41,12,9,74,15]:
    if smallest is not 0:
        smallest=value
    elif value<smallest:
        smallest=value
    print(smallest, value)
# Out:
# 0 3
# 0 41
# 0 12
# 0 9
# 0 74
# 0 15
# <>:3: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:3: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-13-0a11bde82360>:3: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if smallest is not 0:

# %%
hours=int(input("Enter the hours:"))
rate=float(input("Enetr the rate:"))
print(hours*rate)
# Out:
# Enter the hours:4
# Enetr the rate: 0.5
# 2.0
